# %% [markdown]
# # adault's income

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("D:\\tala\\mashin learning\\adult.csv")
df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.describe()
# Out:
#                 age        fnlwgt  education.num  capital.gain  capital.loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours.per.week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# dealing with age column

# %%
sns.displot(df["age"])

# %%
#fing outliers
sns.boxplot(df["age"])
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age'>

# %%
#droping the outliers of age column
drop_index=df[df["age"]>75].index

# %%
df=df.drop(drop_index , axis=0)

# %%
sns.boxplot(df["age"])
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age'>

# %%
sns.displot(df["age"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32320 entries, 2 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32320 non-null  int64
#  1   workclass       32320 non-null  object
#  2   fnlwgt          32320 non-null  int64
#  3   education       32320 non-null  object
#  4   education.num   32320 non-null  int64
#  5   marital.status  32320 non-null  object
#  6   occupation      32320 non-null  object
#  7   relationship    32320 non-null  object
#  8   race            32320 non-null  object
#  9   sex             32320 non-null  object
#  10  capital.gain    32320 non-null  int64
#  11  capital.loss    32320 non-null  int64
#  12  hours.per.week  32320 non-null  int64
#  13  native.country  32320 non-null  object
#  14  income          32320 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.9+ MB

# %% [markdown]
# dealing with workclass column

# %%
df["workclass"].value_counts()
# Out:
# Private             22601
# Self-emp-not-inc     2502
# Local-gov            2077
# ?                    1767
# State-gov            1297
# Self-emp-inc         1098
# Federal-gov           957
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
df["workclass"]=df["workclass"].replace("?" , "unknown")

# %%
df["workclass"].value_counts()
# Out:
# Private             22601
# Self-emp-not-inc     2502
# Local-gov            2077
# unknown              1767
# State-gov            1297
# Self-emp-inc         1098
# Federal-gov           957
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
sns.countplot(df["workclass"])
plt.xticks(rotation=90);
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# dealing with fnlwgt

# %%
sns.displot(df["fnlwgt"])

# %%
sns.boxplot(df["fnlwgt"])
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='fnlwgt'>

# %%
q=df["fnlwgt"].quantile(0.97)
data_1=df[df["fnlwgt"]<q]

# %%
sns.boxplot(data_1["fnlwgt"])
plt.xticks(rotation=90);
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
drop_in=data_1[data_1["fnlwgt"]>=390000].index

# %%
data_2=data_1.drop(drop_in , axis=0)

# %%
sns.boxplot(data_2["fnlwgt"])
plt.xticks(rotation=90);
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# dealing with education

# %%
data_2["education"].value_counts()
# Out:
# HS-grad         9971
# Some-college    6944
# Bachelors       5107
# Masters         1651
# Assoc-voc       1327
# 11th            1115
# Assoc-acdm      1018
# 10th             878
# 7th-8th          584
# Prof-school      558
# 9th              472
# 12th             405
# Doctorate        387
# 5th-6th          291
# 1st-4th          144
# Preschool         46
# Name: education, dtype: int64

# %%
data_2["education"]=data_2["education"].replace(["11th","10th","7th-8th","Prof-school","9th","12th","5th-6th","1st-4th","Preschool","HS-grad"] ,"school")

# %%
data_2["education"]=data_2["education"].replace(["Some-college","Assoc-voc","Assoc-acdm" ,"Bachelors"] , "university")

# %%
data_2["education"].value_counts()
# Out:
# school        14464
# university    14396
# Masters        1651
# Doctorate       387
# Name: education, dtype: int64

# %%
sns.countplot(data_2["education"])
plt.xticks(rotation=90);
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# dealing with education.num

# %%
sns.displot(data_2["education.num"])

# %%
data_2["education.num"].value_counts()
# Out:
# 9     9971
# 10    6944
# 13    5107
# 14    1651
# 11    1327
# 7     1115
# 12    1018
# 6      878
# 4      584
# 15     558
# 5      472
# 8      405
# 16     387
# 3      291
# 2      144
# 1       46
# Name: education.num, dtype: int64

# %%
data_2=data_2.drop("education.num" , axis=1)

# %% [markdown]
# dealing with marital.status

# %%
data_2["marital.status"].value_counts()
# Out:
# Married-civ-spouse       14248
# Never-married            10106
# Divorced                  4269
# Separated                  970
# Widowed                    890
# Married-spouse-absent      395
# Married-AF-spouse           20
# Name: marital.status, dtype: int64

# %%
sns.countplot(data_2["marital.status"])
plt.xticks(rotation=90);
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data_2["marital.status"]=data_2["marital.status"].replace(["Married-civ-spouse","Married-AF-spouse"] , "married")

# %%
data_2["marital.status"]=data_2["marital.status"].replace(["Never-married","Divorced","Separated","Married-spouse-absent","Widowed"] , "single")

# %%
sns.countplot(data_2["marital.status"])
plt.xticks(rotation=90);
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# dealig with occupation

# %%
data_2["occupation"].value_counts()
# Out:
# Prof-specialty       3965
# Craft-repair         3891
# Exec-managerial      3875
# Adm-clerical         3580
# Sales                3471
# Other-service        3127
# Machine-op-inspct    1919
# ?                    1692
# Transport-moving     1526
# Handlers-cleaners    1273
# Farming-fishing       932
# Tech-support          885
# Protective-serv       616
# Priv-house-serv       137
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
data_2["occupation"]=data_2["occupation"].replace("?","Other-service")

# %%
data_2["occupation"]=data_2["occupation"].replace(["Prof-specialty","Sales","Tech-support"] , "proficient")
data_2["occupation"]=data_2["occupation"].replace(["Exec-managerial","Adm-clerical","Machine-op-inspct","Armed-Forces"] , "employee")
data_2["occupation"]=data_2["occupation"].replace(["Craft-repair","Transport-moving","Handlers-cleaners","Farming-fishing","Protective-serv","Priv-house-serv"] , "low_job")

# %%
sns.countplot(data_2["occupation"])
plt.xticks(rotation=90);
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# dealing with relationship

# %%
data_2["relationship"].value_counts()
# Out:
# Husband           12547
# Not-in-family      7836
# Own-child          4830
# Unmarried          3271
# Wife               1504
# Other-relative      910
# Name: relationship, dtype: int64

# %%
data_2["relationship"]=data_2["relationship"].replace(["Husband","Wife","Own-child"] , "relation")
data_2["relationship"]=data_2["relationship"].replace(["Not-in-family","Unmarried"] , "unrelation")

# %%
sns.countplot(data_2["relationship"])
plt.xticks(rotation=90);
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# dealing with race

# %%
data_2["race"].value_counts()
# Out:
# White                 26478
# Black                  2827
# Asian-Pac-Islander     1025
# Amer-Indian-Eskimo      307
# Other                   261
# Name: race, dtype: int64

# %%
sns.countplot(data_2["race"])
plt.xticks(rotation=90);
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# dealing with sex

# %%
data_2["sex"].value_counts()
# Out:
# Male      20606
# Female    10292
# Name: sex, dtype: int64

# %%
sns.countplot(data_2["sex"])
plt.xticks(rotation=90);
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# dealing with capital.gain

# %%
sns.displot(data_2["capital.gain"])

# %%
data_2["capital.gain"].value_counts()
# Out:
# 0        28320
# 15024      336
# 7688       275
# 7298       238
# 99999      150
#          ...
# 6097         1
# 2062         1
# 5060         1
# 2387         1
# 22040        1
# Name: capital.gain, Length: 118, dtype: int64

# %%
data_2["capital.gain"]=data_2["capital.gain"].replace(0 ,"no")

# %%
data_2["capital.gain"]=data_2["capital.gain"].replace(range(1,100000) ,"yes")

# %%
data_2["capital.gain"].value_counts()
# Out:
# no     28320
# yes     2578
# Name: capital.gain, dtype: int64

# %%
sns.countplot(data_2["capital.gain"])
plt.xticks(rotation=90);
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# dealing with capital.loss

# %%
sns.displot(data_2["capital.loss"])

# %%
data_2["capital.loss"].value_counts()
# Out:
# 0       29440
# 1902      194
# 1977      163
# 1887      153
# 1848       50
#         ...
# 2080        1
# 3683        1
# 1411        1
# 1844        1
# 4356        1
# Name: capital.loss, Length: 89, dtype: int64

# %%
data_2["capital.loss"]=data_2["capital.loss"].replace(0 ,"no")
data_2["capital.loss"]=data_2["capital.loss"].replace(range(1,5000) ,"yes")

# %%
sns.countplot(data_2["capital.loss"])
plt.xticks(rotation=90);
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data_2.head()
# Out:
#    age workclass  fnlwgt   education marital.status     occupation  \
# 2   66   unknown  186061  university         single  Other-service
# 3   54   Private  140359      school         single       employee
# 4   41   Private  264663  university         single     proficient
# 5   34   Private  216864      school         single  Other-service
# 6   38   Private  150601      school         single       employee
#
#   relationship   race     sex capital.gain capital.loss  hours.per.week  \
# 2   unrelation  Black  Female           no          yes              40
# 3   unrelation  White  Female           no          yes              40
# 4     relation  White  Female           no          yes              40
# 5   unrelation  White  Female           no          yes              45
# 6   unrelation  White    Male           no          yes              40
#
#   native.country income
# 2  United-States  <=50K
# 3  United-States  <=50K
# 4  United-States  <=50K
# 5  United-States  <=50K
# ...

# %%
sns.kdeplot(data_2["hours.per.week"])
# Out:
# <AxesSubplot:xlabel='hours.per.week', ylabel='Density'>

# %%
sns.boxplot(data_2["hours.per.week"])
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='hours.per.week'>

# %%
data_2["hours.per.week"].min()
# Out:
# 1

# %%
data_2["hours.per.week"].max()
# Out:
# 99

# %%
drop_index_right=data_2[data_2["hours.per.week"]>70].index

# %%
data_3=data_2.drop(drop_index_right , axis=0)

# %%
sns.boxplot(data_3["hours.per.week"])
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='hours.per.week'>

# %%
drop_index_left=data_3[data_3["hours.per.week"]<15].index

# %%
data_3=data_3.drop(drop_index_left , axis=0)

# %%
sns.boxplot(data_3["hours.per.week"])
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='hours.per.week'>

# %% [markdown]
# dealing with native.country

# %%
data_3["native.country"].value_counts()
# Out:
# United-States                 26547
# ?                               528
# Mexico                          492
# Philippines                     188
# Germany                         128
# Canada                          107
# Puerto-Rico                     105
# India                            96
# El-Salvador                      89
# Cuba                             88
# England                          80
# Jamaica                          79
# South                            74
# China                            70
# Dominican-Republic               66
# Italy                            63
# Vietnam                          61
# Japan                            56
# Columbia                         55
# Poland                           53
# Guatemala                        50
# Taiwan                           46
# Haiti                            42
# Iran                             41
# Portugal                         35
# Nicaragua                        28
# ...

# %%
plt.figure(figsize=(12,8) , dpi=200)
sns.countplot(df["native.country"])
plt.xticks(rotation=90);
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data_3=data_3.drop("native.country",axis=1)

# %%
data_3["income"].value_counts()
# Out:
# <=50K    22282
# >50K      7261
# Name: income, dtype: int64

# %%
data_3.head()
# Out:
#    age workclass  fnlwgt   education marital.status     occupation  \
# 2   66   unknown  186061  university         single  Other-service
# 3   54   Private  140359      school         single       employee
# 4   41   Private  264663  university         single     proficient
# 5   34   Private  216864      school         single  Other-service
# 6   38   Private  150601      school         single       employee
#
#   relationship   race     sex capital.gain capital.loss  hours.per.week income
# 2   unrelation  Black  Female           no          yes              40  <=50K
# 3   unrelation  White  Female           no          yes              40  <=50K
# 4     relation  White  Female           no          yes              40  <=50K
# 5   unrelation  White  Female           no          yes              45  <=50K
# 6   unrelation  White    Male           no          yes              40  <=50K

# %%
data_3["income"]=data_3["income"].map({"<=50K":0 ,">50K":1})

# %%
data_3["income"].value_counts()
# Out:
# 0    22282
# 1     7261
# Name: income, dtype: int64

# %%
data_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29543 entries, 2 to 32560
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             29543 non-null  int64
#  1   workclass       29543 non-null  object
#  2   fnlwgt          29543 non-null  int64
#  3   education       29543 non-null  object
#  4   marital.status  29543 non-null  object
#  5   occupation      29543 non-null  object
#  6   relationship    29543 non-null  object
#  7   race            29543 non-null  object
#  8   sex             29543 non-null  object
#  9   capital.gain    29543 non-null  object
#  10  capital.loss    29543 non-null  object
#  11  hours.per.week  29543 non-null  int64
#  12  income          29543 non-null  int64
# dtypes: int64(4), object(9)
# memory usage: 3.2+ MB

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data_3.corr() ,annot=True )
# Out:
# <AxesSubplot:>

# %%
data_4=pd.get_dummies(data_3 , drop_first=True)

# %%
data_4.head()
# Out:
#    age  fnlwgt  hours.per.week  income  workclass_Local-gov  \
# 2   66  186061              40       0                    0
# 3   54  140359              40       0                    0
# 4   41  264663              40       0                    0
# 5   34  216864              45       0                    0
# 6   38  150601              40       0                    0
#
#    workclass_Never-worked  workclass_Private  workclass_Self-emp-inc  \
# 2                       0                  0                       0
# 3                       0                  1                       0
# 4                       0                  1                       0
# 5                       0                  1                       0
# 6                       0                  1                       0
#
#    workclass_Self-emp-not-inc  workclass_State-gov  ...  \
# 2                           0                    0  ...
# 3                           0                    0  ...
# ...

# %%
data_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29543 entries, 2 to 32560
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   age                         29543 non-null  int64
#  1   fnlwgt                      29543 non-null  int64
#  2   hours.per.week              29543 non-null  int64
#  3   income                      29543 non-null  int64
#  4   workclass_Local-gov         29543 non-null  uint8
#  5   workclass_Never-worked      29543 non-null  uint8
#  6   workclass_Private           29543 non-null  uint8
#  7   workclass_Self-emp-inc      29543 non-null  uint8
#  8   workclass_Self-emp-not-inc  29543 non-null  uint8
#  9   workclass_State-gov         29543 non-null  uint8
#  10  workclass_Without-pay       29543 non-null  uint8
#  11  workclass_unknown           29543 non-null  uint8
#  12  education_Masters           29543 non-null  uint8
# ...

# %%
df_prepro=data_4.copy()

# %%
inputs=df_prepro.drop(["income"], axis=1)
target=df_prepro["income"]

# %%
from sklearn.model_selection import train_test_split

x_train ,x_other , y_train , y_other=train_test_split(inputs , target , test_size=0.2 , random_state=42)
x_valid ,x_test , y_valid , y_test=train_test_split(x_other , y_other , test_size=0.5 , random_state=42)

# %% [markdown]
# # Machine learning modelings

# %% [markdown]
# # LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression

log=LogisticRegression()
log.fit(x_train , y_train)                                      

log_pred=log.predict(x_valid)

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_valid , log_pred))
# Out:
# [[2264    0]
#  [ 690    0]]

# %%
from sklearn.metrics import plot_confusion_matrix

plot_confusion_matrix(log ,x_valid , y_valid)
# Out:
# C:\Anaconda\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_valid,log_pred)
# Out:
# 0.7664184157075152

# %%
error=1-accuracy_score(y_valid,log_pred)
error
# Out:
# 0.23358158429248477

# %% [markdown]
# # LogisticRegressionCV

# %%
from sklearn.linear_model import LogisticRegressionCV

log_cv=LogisticRegressionCV()
log_cv.fit(x_train, y_train)
# Out:
# LogisticRegressionCV()

# %%
log_cv.Cs_
# Out:
# array([1.00000000e-04, 7.74263683e-04, 5.99484250e-03, 4.64158883e-02,
#        3.59381366e-01, 2.78255940e+00, 2.15443469e+01, 1.66810054e+02,
#        1.29154967e+03, 1.00000000e+04])

# %%
log_cv.C_
# Out:
# array([0.0001])

# %%
log_cv_pred=log_cv.predict(x_valid)

# %%
print(confusion_matrix(y_valid , log_cv_pred))
# Out:
# [[2264    0]
#  [ 690    0]]

# %%
accuracy_score(y_valid,log_cv_pred)
# Out:
# 0.7664184157075152

# %%
error=1-accuracy_score(y_valid,log_cv_pred)
error
# Out:
# 0.23358158429248477

# %% [markdown]
# # RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

rfc=RandomForestClassifier(n_estimators=200 ,max_features=5) 
rfc.fit(x_train ,y_train)                     
pred_rfc=rfc.predict(x_valid)

# %%
print(confusion_matrix(y_valid , pred_rfc))
# Out:
# [[2037  227]
#  [ 288  402]]

# %%
accuracy_score(y_valid,pred_rfc)
# Out:
# 0.8256601218686527

# %%
error=1-accuracy_score(y_valid,pred_rfc)
error
# Out:
# 0.17433987813134733

# %% [markdown]
# # SVC

# %%
from sklearn.svm import SVC

svc=SVC()
svc.fit(x_train ,y_train) 
pred_svc=svc.predict(x_valid)

# %%
print(confusion_matrix(y_valid , pred_svc))
# Out:
# [[2264    0]
#  [ 690    0]]

# %%
accuracy_score(y_valid,pred_svc)
# Out:
# 0.7664184157075152

# %%
error=1-accuracy_score(y_valid,pred_svc)
error
# Out:
# 0.23358158429248477

# %% [markdown]
# # SVM

# %%
from sklearn import svm
from sklearn.svm import SVC
svm=svm.SVC()
svm.fit(x_train ,y_train) 
pred_svm=svm.predict(x_valid)

# %%
print(confusion_matrix(y_valid , pred_svm))
# Out:
# [[2264    0]
#  [ 690    0]]

# %%
accuracy_score(y_valid,pred_svm)
# Out:
# 0.7664184157075152

# %%
error=1-accuracy_score(y_valid,pred_svm)
error
# Out:
# 0.23358158429248477

# %% [markdown]
# # DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier

dtc=DecisionTreeClassifier(random_state=42)
dtc.fit(x_train , y_train)
dtc_pred=dtc.predict(x_valid)

# %%
print(confusion_matrix(y_valid , dtc_pred))
# Out:
# [[1905  359]
#  [ 292  398]]

# %%
accuracy_score(y_valid,dtc_pred)
# Out:
# 0.7796208530805687

# %%
error=1-accuracy_score(y_valid,dtc_pred)
error
# Out:
# 0.22037914691943128

# %%
from sklearn.tree import plot_tree

plt.figure(figsize=(12,8) , dpi=200)
plot_tree(dtc);

# %% [markdown]
# # KNeighborsClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier

knn=KNeighborsClassifier(n_neighbors=2)

knn.fit(x_train , y_train)

knn_pred=knn.predict(x_valid)

# %%
print(confusion_matrix(y_valid , knn_pred))
# Out:
# [[2114  150]
#  [ 587  103]]

# %%
accuracy_score(y_valid,knn_pred)
# Out:
# 0.7505077860528098

# %%
error=1-accuracy_score(y_valid,knn_pred)
error
# Out:
# 0.24949221394719023

# %% [markdown]
# # MLPClassifier

# %%
from sklearn.neural_network import MLPClassifier

mlpc=MLPClassifier(hidden_layer_sizes=(11,11,11) , max_iter=500)
mlpc.fit(x_train , y_train)
pred_mlpc=mlpc.predict(x_valid)

# %%
print(confusion_matrix(y_valid , pred_mlpc))
# Out:
# [[2241   23]
#  [ 674   16]]

# %%
accuracy_score(y_valid,pred_mlpc)
# Out:
# 0.7640487474610698

# %%
error=1-accuracy_score(y_valid,pred_mlpc)
error
# Out:
# 0.23595125253893023

# %% [markdown]
# # AdaBoostClassifier

# %%
from sklearn.ensemble import AdaBoostClassifier

abc=AdaBoostClassifier()
abc.fit(x_train , y_train)
abc_pred=abc.predict(x_valid)

# %%
print(confusion_matrix(y_valid , abc_pred))
# Out:
# [[2065  199]
#  [ 288  402]]

# %%
accuracy_score(y_valid,abc_pred)
# Out:
# 0.8351387948544347

# %%
error=1-accuracy_score(y_valid,abc_pred)
error
# Out:
# 0.16486120514556535

# %% [markdown]
# # GradientBoostingClassifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

gbc=GradientBoostingClassifier()
gbc.fit(x_train, y_train)
gbc_pred=gbc.predict(x_valid)

# %%
print(confusion_matrix(y_valid , gbc_pred))
# Out:
# [[2059  205]
#  [ 274  416]]

# %%
accuracy_score(y_valid,gbc_pred)
# Out:
# 0.8378469871360866

# %%
error=1-accuracy_score(y_valid,gbc_pred)
error
# Out:
# 0.16215301286391337

# %% [markdown]
# # PassiveAggressiveClassifier

# %%
from sklearn.linear_model import PassiveAggressiveClassifier

pac=PassiveAggressiveClassifier()
pac.fit(x_train , y_train)
pac_pred=pac.predict(x_valid)

# %%
print(confusion_matrix(y_valid , pac_pred))
# Out:
# [[2264    0]
#  [ 690    0]]

# %%
accuracy_score(y_valid,pac_pred)
# Out:
# 0.7664184157075152

# %%
error=1-accuracy_score(y_valid,pac_pred)
error
# Out:
# 0.23358158429248477

# %% [markdown]
# # accuracy and errors dataframe

# %%
algorithem=["Logistic","LogisticCV","RandomForest","SVC" ,"SVM","DecisionTree","KNeighborsr","MLP","Ada","Gradient","Passive"]

# %%
acc=[0.766,0.766,0.825,0.766,0.766,0.779,0.750,0.764,0.835,0.837,0.766]

# %%
result_df=pd.DataFrame(columns=["algorithem"] , data=algorithem )
result_df
# Out:
#       algorithem
# 0       Logistic
# 1     LogisticCV
# 2   RandomForest
# 3            SVC
# 4            SVM
# 5   DecisionTree
# 6    KNeighborsr
# 7            MLP
# 8            Ada
# 9       Gradient
# 10       Passive

# %%
accuracy=pd.Series(acc)
result_df["accuracy"]=accuracy
result_df
# Out:
#       algorithem  accuracy  errors
# 0       Logistic     0.766     NaN
# 1     LogisticCV     0.766     NaN
# 2   RandomForest     0.825     NaN
# 3            SVC     0.766     NaN
# 4            SVM     0.766     NaN
# 5   DecisionTree     0.779     NaN
# 6    KNeighborsr     0.750     NaN
# 7            MLP     0.764     NaN
# 8            Ada     0.835     NaN
# 9       Gradient     0.837     NaN
# 10       Passive     0.766     NaN

# %%
result_df["1"]=1

# %%
result_df["errors"]=result_df["1"]-result_df["accuracy"]

# %%
result_df=result_df.drop("1", axis=1)

# %%
result_df
# Out:
#       algorithem  accuracy  errors
# 0       Logistic     0.766   0.234
# 1     LogisticCV     0.766   0.234
# 2   RandomForest     0.825   0.175
# 3            SVC     0.766   0.234
# 4            SVM     0.766   0.234
# 5   DecisionTree     0.779   0.221
# 6    KNeighborsr     0.750   0.250
# 7            MLP     0.764   0.236
# 8            Ada     0.835   0.165
# 9       Gradient     0.837   0.163
# 10       Passive     0.766   0.234

# %%
sns.barplot(data=result_df , x="algorithem" ,y="accuracy")
plt.xticks(rotation=90);

# %%
sns.barplot(data=result_df , x="algorithem" ,y="errors")
plt.xticks(rotation=90);

# %%
log_test=log.predict(x_test)
log_cv_test_=log_cv.predict(x_test)
rfc_tesr=rfc.predict(x_test)
svc_test=svc.predict(x_test)
svm_test=svm.predict(x_test)
dtc_test=dtc.predict(x_test)
knn_test=knn.predict(x_test)
mlp_test=mlpc.predict(x_test)
abc_test=abc.predict(x_test)
gac_test=gbc.predict(x_test)
pac_test=pac.predict(x_test)

# %%
sns.scatterplot(data=df ,x"y_test" ,"log_test")
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [197], in <cell line: 1>()
# ----> 1 sns.scatterplot("y_test" ,"log_test")
#
# File C:\Anaconda\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
# ...
